# %%
# Q1

'''
Flask is a pythonic Framework or library to build web API's between applications.

Flask is very easy to use, scaliable, flexiable , Extensibility

'''
# Out:
# "\nFlask is a pythonic Framework or library to build web API's between applications.\n\nFlask is very easy to use, scaliable, flexiable , Extensibility\n\n"

# %%
#Q2

# %% [markdown]
# ![Flask-APP.png](attachment:f660ac4e-3067-4093-88fa-edb0ceb0c1fe.png)

# %%
# Q3

'''
App routing is a decoration function
We use to build an addres and to be able to acceses the function or the code output throw a url

'''
# Out:
# '\nApp routing is a decoration function\nWe use to build an addres and to be able to acceses the function or the code output throw a url\n\n'

# %%
# Q4
'''
from flask import Flask

app = Flask(__name__)

@app.route("/welcome")
def hello_world():
    return "Welcome to ABC Corporation"

@app.route("/")
def hello_world2():
    return '''
    <pre>
    Company Name :ABC Corporation
    Location India
    Contact Details: 999-999-9999
    </pre>
    '''


if __name__=="__main__":
    app.run(host="0.0.0.0")
    
'''
# Out:
#   Cell In[1], line 14
#     <pre>
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# ![Flask2.png](attachment:9b021cf2-0239-460a-97e8-a4fdda0e89e1.png)

# %% [markdown]
# ![flask1.png](attachment:992610c5-da19-4d84-9189-aea329aa7afb.png)
