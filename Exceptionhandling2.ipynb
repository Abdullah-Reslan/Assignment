# %%
# Q1
'''
The reason is that it's difficult to contain all exception cases in my custom class.
That's why we need to use the superclass Exception to inherit all exceptions that may arise.

'''
# Out:
# "\nThe reason is that it's difficult to contain all exception cases in my custom class.\nThat's why we need to use the superclass Exception to inherit all exceptions that may arise.\n\n"

# %%
# Q2
def get_all_subclasses(cls):
    all_subclasses = []
    
    for subclass in cls.__subclasses__():
        all_subclasses.append(subclass)
        all_subclasses.extend(get_all_subclasses(subclass))
    return all_subclasses

# %%
get_all_subclasses(Exception)
# Out:
# [TypeError,
#  decimal.FloatOperation,
#  email.errors.MultipartConversionError,
#  StopAsyncIteration,
#  StopIteration,
#  ImportError,
#  ModuleNotFoundError,
#  zipimport.ZipImportError,
#  OSError,
#  ConnectionError,
#  BrokenPipeError,
#  ConnectionAbortedError,
#  ConnectionRefusedError,
#  ConnectionResetError,
#  http.client.RemoteDisconnected,
#  BlockingIOError,
#  ChildProcessError,
#  FileExistsError,
#  FileNotFoundError,
#  IsADirectoryError,
#  NotADirectoryError,
#  InterruptedError,
#  zmq.error.InterruptedSystemCall,
#  PermissionError,
#  ProcessLookupError,
#  TimeoutError,
#  io.UnsupportedOperation,
#  signal.itimer_error,
#  socket.herror,
#  socket.gaierror,
#  ssl.SSLError,
#  ssl.SSLCertVerificationError,
#  ssl.SSLZeroReturnError,
#  ssl.SSLWantWriteError,
#  ssl.SSLWantReadError,
#  ssl.SSLSyscallError,
#  ssl.SSLEOFError,
#  shutil.Error,
#  shutil.SameFileError,
#  shutil.SpecialFileError,
#  shutil.ExecError,
#  shutil.ReadError,
# ...

# %%
# Q3

'''

FloatingPointError
OverflowError
ZeroDivisionError

'''
# Out:
# '\n\nFloatingPointError\nOverflowError\nZeroDivisionError\n\n'

# %%
# ZerodivisionError
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # ZerodivisionError
# ----> 2 1/0
#
# ZeroDivisionError: division by zero

# %%
# OverflowError
n = 9999.9999

for i in range(2,1000):
    n= n**i
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[42], line 5
#       2 n = 9999.9999
#       4 for i in range(2,1000):
# ----> 5     n= n**i
#
# OverflowError: (34, 'Numerical result out of range')

# %%
# Q4

'''
The LookupError class is used to handle exceptions that occur 
when a key or index is used on a mapping or sequence that is not valid.
'''
# Out:
# '\nThe LookupError class is used to handle exceptions that occur \nwhen a key or index is used on a mapping or sequence that is not valid.\n'

# %%
dic={"name":"Reslan", "Age":"27", "email_id":"reslan@gmail.com"}
try:
    
    val = dic["Address"]
except KeyError as e:
    print(f"KeyError is {e} ")
# Out:
# KeyError is 'Address'

# %%
lst = [1,2,3,4]
try:
    val = lst[5]
    
except IndexError as e:
    print(f"This is an Index Error and its out of range {e} ")
# Out:
# This is an Index Error and its out of range list index out of range

# %%
# Q5
'''

Import Error is an error that occur when we are trying to import a not existed Module
or when the module is not installed.

Regarding ModuleNotFoundError it is a subclass for ImportError, so basically
when im trying to import a Module that not exicted , this error will show up 

'''
# Out:
# '\n\nImport Error is an error that occur when we are trying to import a not existed Module\nor when the module is not installed.\n\nRegarding ModuleNotFoundError it is a subclass for ImportError, so basically\nwhen im trying to import a Module that not exicted , this error will show up \n\n'

# %%
# Q6 
'''
1. Be specific in Except Clauses
2. Use else Block sparingly
3. Use finally for Cleanup
4. Avoid Using Exception for Controlflow
5. Log Exceptions
6. Coustom Exception
7. Handle Resource Cleanup with with statment
8. Avoid silent Features
9. 
'''
